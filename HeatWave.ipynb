# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.utils import resample
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# **Data Collection and Processing**

# %%
#load the dataset into a pandas dataframe
data = pd.read_csv('/content/Pandemic.csv')

# %%
data.shape
# Out:
# (272, 6)

# %%
data.head()
# Out:
#    Unnamed: 0  Epidemics/pandemics           Disease  \
# 0           0          Black Death    Bubonic plague
# 1           1          Spanish flu  Influenza A/H1N1
# 2           2  Plague of Justinian    Bubonic plague
# 3           3    HIV/AIDS epidemic          HIV/AIDS
# 4           4    COVID-19 pandemic          COVID-19
#
#                             Death toll             Date  \
# 0                       75–200 million        1346–1353
# 1                       17–100 million        1918–1920
# 2                       15–100 million          541–549
# 3             40.1 million (as of 2021     1981–present
# 4  7–28.3 million (as of December 2022  2019[c]–present
#
#                                 Location
# 0         Europe, Asia, and North Africa
# 1                              Worldwide
# 2  North Africa, Europe and Western Asia
# 3                              Worldwide
# 4                              Worldwide

# %%
print("Data Info:")
data.info()
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           272 non-null    int64
#  1   Epidemics/pandemics  272 non-null    object
#  2   Disease              272 non-null    object
#  3   Death toll           272 non-null    object
#  4   Date                 272 non-null    object
#  5   Location             272 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 12.9+ KB

# %%
# remove extra  spaces in all columns
data.columns = data.columns.str.strip()

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Epidemics/pandemics', 'Disease', 'Death toll', 'Date',
#        'Location'],
#       dtype='object')

# %%
data.rename(columns={'Unnamed: 0': 'ID'}, inplace=True)
display(data.head())
# Out:
#    ID  Epidemics/pandemics           Disease  \
# 0   0          Black Death    Bubonic plague
# 1   1          Spanish flu  Influenza A/H1N1
# 2   2  Plague of Justinian    Bubonic plague
# 3   3    HIV/AIDS epidemic          HIV/AIDS
# 4   4    COVID-19 pandemic          COVID-19
#
#                             Death toll             Date  \
# 0                       75–200 million        1346–1353
# 1                       17–100 million        1918–1920
# 2                       15–100 million          541–549
# 3             40.1 million (as of 2021     1981–present
# 4  7–28.3 million (as of December 2022  2019[c]–present
#
#                                 Location
# 0         Europe, Asia, and North Africa
# 1                              Worldwide
# 2  North Africa, Europe and Western Asia
# 3                              Worldwide
# 4                              Worldwide

# %%
# removing the serial number since its coming twice
data = data.drop(columns = 'ID')

# %%
data.head()
# Out:
#    Epidemics/pandemics           Disease                           Death toll  \
# 0          Black Death    Bubonic plague                       75–200 million
# 1          Spanish flu  Influenza A/H1N1                       17–100 million
# 2  Plague of Justinian    Bubonic plague                       15–100 million
# 3    HIV/AIDS epidemic          HIV/AIDS             40.1 million (as of 2021
# 4    COVID-19 pandemic          COVID-19  7–28.3 million (as of December 2022
#
#               Date                               Location
# 0        1346–1353         Europe, Asia, and North Africa
# 1        1918–1920                              Worldwide
# 2          541–549  North Africa, Europe and Western Asia
# 3     1981–present                              Worldwide
# 4  2019[c]–present                              Worldwide

# %%
data.describe()
# Out:
#             Epidemics/pandemics         Disease Death toll  Date   Location
# count                       272             272        272   272        272
# unique                      262              77        202   219        167
# top     2009 swine flu pandemic  Bubonic plague    Unknown  2008  Worldwide
# freq                          2              57         31     6         27

# %%
# checking the number of missing values
print(data.isnull().sum())
# Out:
# Epidemics/pandemics    0
# Disease                0
# Death toll             0
# Date                   0
# Location               0
# dtype: int64

# %%
data["Location"].unique()
